# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        data = pickle.load(fo, encoding='bytes')
    return data

# %%
#data_dir = "dummy"
data_dir = ""

# %%
path_train = [data_dir + "/data_batch_" + str(i) for i in range(1, 6)]
path_test = data_dir + "/test_batch"

# %%
path_train

# %%
path_test

# %%
path_train = [data_dir + "data_batch_" + str(i) for i in range(1, 6)]
path_test = data_dir + "test_batch"
data_batch = unpickle(path_test)

# %%
data_batch.keys()

# %%
data_batch[b"data"].shape

# %%
np.array(data_batch[b"labels"]).shape

# %%
Xtrain = data_batch[b"data"]

# %%
Xtrain.shape

# %%
raw_shape = [10000, 3, 32, 32]
indices_transpose = [0, 2, 3, 1]
new_shape = [10000, 32, 32, 3]

# %%
Xtrain = np.reshape(Xtrain, raw_shape)

# %%
print(Xtrain[0, 0])

# %%
Xtrain = np.transpose(Xtrain, indices_transpose)

# %%
plt.figure(figsize=(1.5,1.5))

plt.imshow(X_test[8])

plt.show()
plt.close()

# %%
data_batch[b"labels"]

# %%
data_batch[b"filenames"]

# %%
data_batch.keys()

# %%
import numpy as np

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        data = pickle.load(fo, encoding='bytes')
    return data

# %%
imported_shape = [10000, 3, 32, 32]
indices_transpose = [0, 2, 3, 1]
new_shape = [10000, 32, 32, 3]

# %%
path_train = ["data_batch_" + str(i) for i in range(1, 6)]
path_test = "test_batch"

# %%
train_data_list = list()
train_label_list = list()
for batch in path_train:
    data_batch = unpickle(batch)
    images = np.transpose(np.reshape(data_batch[b"data"], imported_shape), indices_transpose)
    train_data_list.append(images)
    train_label_list = train_label_list + data_batch[b'labels']
X_train = np.concat(train_data_list, axis=0).astype(np.float32) / 255.0
Y_train = np.array(train_label_list)#.astype(np.int64)

# %%
data_batch = unpickle(path_test)
X_test = np.transpose(np.reshape(data_batch[b"data"], imported_shape), indices_transpose).astype(np.float32) / 255.0
Y_test = np.array(data_batch[b'labels'])

# %%
images = images.astype(np.float32) / 255.0

# %%
test_data_list = list()
train_label_list = list()
for batch in path_train:
    data_batch = unpickle(batch)
    images = np.transpose(np.reshape(data_batch[b"data"], imported_shape), indices_transpose)
    train_data_list.append(images)
    train_label_list = train_label_list + data_batch[b'labels']
X_train = np.concat(train_data_list, axis=0).astype(np.float32) / 255.0
Y_train = np.array(train_label_list)#.astype(np.int64)

# %%
X_train = np.array(train_data_list).astype(np.float32)

# %%
type(data_batch[b"labels"][0])

# %%
np.array(data_batch[b"labels"]).dtype

# %%
X_train.shape

# %%
np.transpose(np.reshape(data_batch[b"data"], imported_shape), indices_transpose).shape

# %%
X_train = np.concat(train_data_list, axis=0)

# %%
X_train.shape
